# %% [markdown]
# <a href="https://colab.research.google.com/github/dang02032007nd-del/thuchanhTDTT-nguyenhaidang25021718/blob/main/homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bai 1
n = input("Nhap mot so nguyen: ")
n = int(n)
print(n*2)
# Out:
# Nhap mot so nguyen: 3
# 6

# %%
#bai 2
a = int(input("Nhap chieu dai"))
b = int(input("Nhap chieu rong"))
radius = min(a, b)/2
print("Dien tich trong cay xung quanh la:", a*b - 3.14*(radius**2))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-126349828.py in <cell line: 0>()
#       1 #bai 2
# ----> 2 a = int(input("Nhap chieu dai"))
#       3 b = int(input("Nhap chieu rong"))
#       4 radius = min(a, b)/2
#       5 print("Dien tich trong cay xung quanh la:", a*b - 3.14*(radius**2))
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#bai 3
c = input("Hay nhap 1 ki tu: ")
if (ord(c)>=97) :
    print(chr(ord(c)-32))
else :
    print(chr(ord(c)+32))

# %%
#bai 4
c = input("Hay nhap 1 ki tu: ")
if (ord(c)>=65 and ord(c)<=122) :
    print(f"{c} la ki tu alphabet")
else :
    print(f"{c} khong phai la ki tu alphabet")

# %%
#bai 5
c = input("Nhap 1 chu cai in hoa: ")
if (c!='A') :
    print(chr(ord(c)+31))
else :
    print("Truong hop dac biet, khong ton tai ki tu truoc A")

# %%
#bai 6
import math

a = int(input("Nhap canh thu nhat: "))
b = int(input("Nhap canh thu hai: "))
c = int(input("Nhap canh thu ba: "))
num_list = [a, b, c]
sum = a+b+c
p = sum/2
is_triangle = True

for i in num_list:
    if i>=sum-i :
        print("Khong phai 3 canh cua tam giac")
        is_triangle = False
        break

if (is_triangle) :
    area = math.sqrt(p*(p-a)*(p-b)*(p-c))
    print(f"Dien tich tam giac: {area:.1f}") #lam tron 1 chu so thap phan bang f-string

# %%
#bai 7
s = input("Nhap xau ki tu: ")
print("Chu cai thu 5:", s[4])
print("Chu cai thu 9:", s[8])

#index = thu tu - 1

# %%
#bai 8
def negative_to_zero(n):
    if n<0:
        return 0
    else:
        return n

name = input("Ten chu ho: ")
last_month = int(input("Chi so thang truoc: "))
this_month = int(input("Chi so thang nay: "))
so_dien_da_dung = this_month-last_month

bac = [0, 1984, 2050, 2380, 2998, 3350, 3460]
index = 1
total = 0

while so_dien_da_dung>0 :
    if index==1 or index==2:
        total += min(50, negative_to_zero(so_dien_da_dung))*bac[index]
        so_dien_da_dung -= 50
        index+=1
        continue
    total += min(100, negative_to_zero(so_dien_da_dung))*bac[index]
    so_dien_da_dung-=100
    if (index<6) :
        index+=1

total *= 1.08 #VAT 8%

print(f"Ho va ten: {name}")
print(int(total+0.5))

# %% [markdown]
# Bài tập làm thêm

# %%
#bai 1
n = int(input("Hay nhap 1 so nguyen: "))
if n&1==0:
    print("Day la so chan")
else:
    print("Day la so le")

# %%
#bai 2
n = int(input("Hay nhap 1 so nguyen: "))
if n%10==5:
    print("True")
else:
    print("False")

# %%
#bai 3
n = int(input("Hay nhap 1 so nguyen: "))
if n%3==0 and n%5==0:
    print("True")
else:
    print("False")

# %%
#bai 4
#coi nhu nam hien tai la 2025
birthyear = int(input("Hay nhap nam sinh: "))
if 2025-birthyear<18:
    print("Khong du dieu kien tham gia bau cu")
else:
    print("Du dieu kien tham gia bau cu")

# %%
#bai 5
a = int(input("Nhap so thu nhat: "))
b = int(input("Nhap so thu hai: "))
if a==b:
    print("Hai so bang nhau")
else:
    print(f"So lon hon la: {max(a, b)}")

# %%
#bai 6
c = input("Hay nhap mot ki tu: ")
if (ord('0')<=ord(c)<=ord('9')):
    print("Day la mot so")
elif (ord('A')<=ord(c)<=ord('z')):
    print("Day la mot chu cai")
else:
    print("Day khong phai la so cung khong phai la chu")

# %%
#bai 7
diem = float(input("Nhap diem: "))
match diem:
    # 1. Giỏi: >= 8.0
    case _ if diem >= 8.0 and diem <= 10.0:
        print("Hoc luc gioi")
    # 2. Khá: [6.5, 8.0)
    case _ if diem >= 6.5:
        print("Hoc luc kha")
    # 3. Trung bình: [5.0, 6.5)
    case _ if diem >= 5.0:
        print("Hoc luc trung binh")
    # 4. Yếu: [0, 5.0)
    case _ if diem >= 0.0:
        print("Hoc luc yeu")
    # 5. Trường hợp không hợp lệ (ví dụ: điểm âm, điểm > 10)
    case _:
        print("Diem khong hop le")

# %%
#bai 8
nam = int(input("Nhap nam: "))
if nam%400==0 or (nam%4==0 and nam%100!=0):
    print("Day la nam nhuan")
else:
    print("Day khong phai la nam nhuan")

# %%
#bai 9
n = int(input("Nhap 1 so nguyen tu 0 den 9: "))
match n:
    case 0:
        print("Khong")
    case 1:
        print("Mot")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bon")
    case 5:
        print("Nam")
    case 6:
        print("Sau")
    case 7:
        print("Bay")
    case 8:
        print("Tam")
    case 9:
        print("Chin")
    case _:
        print("So khong hop le")

# %%
#bai 10
diem = int(input("Nhap diem thi: "))
if diem>=4:
    print("Qua mon")
else:
    print("Hoc lai")

# %%
#bai 11
birthyear = int(input("Nhap nam sinh: "))
if 2025-birthyear>=18:
    print("Da du 18 tuoi")
else:
    print("Chua du 18 tuoi")
